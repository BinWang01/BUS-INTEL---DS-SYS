# %%
#1 Load pandas and sqlite3 libraries

# %%
import pandas as pd

# %%
import sqlite3 as db

# %%
#2 Get the list of tables

# %%
conn = db.connect('Downloads/The-Pandas-Workshop-master/The-Pandas-Workshop-master/Chapter03/datasets/supply_company.db')

# %%
tablequery = "SELECT name FROM sqlite_master WHERE type = 'table'"

# %%
tables = pd.read_sql(tablequery, conn)

# %%
tables
# Out:
#         name
# 0  Customers
# 1     Orders

# %%
#3 load the table that contains the orders

# %%
ordersquery = "SELECT * FROM Orders"

# %%
orders = pd.read_sql(ordersquery, conn)

# %%
orders
# Out:
#     index  Customer_Number        date        item  qty  price   amount
# 0       0            25058  10/19/2020   354161666   62  91.50  5673.14
# 1       1            25058  11/10/2020  1129038342   38  79.79  3032.14
# 2       2            26069  11/23/2020   421919566   40  55.67  2226.76
# 3       3            26069  12/22/2020  1156861472   54  80.30  4336.03
# 4       4            26858  11/30/2020   936049686   64  45.37  2903.99
# 5       5            26858   12/9/2020   458515506   54  15.55   839.51
# 6       6            26858   11/6/2020   937462037   83  44.92  3728.20
# 7       7            31782  10/21/2020  1056009661   17  38.95   662.14
# 8       8            31782  12/23/2020  1345493738   61  46.32  2825.78
# 9       9            31782   10/6/2020   959143459   73  57.57  4202.92
# 10     10            32791  10/12/2020   742707719   93  34.95  3250.43
# 11     11            32791  11/24/2020  1198322845   84  87.45  7346.21
# ...

# %%
#4 Determine the number of customers with the largest sales

# %%
bestcustomer = orders.groupby('Customer_Number')['amount'].sum().sort_values(ascending = False).index[0]

# %%
bestcustomer
# Out:
# 35549

# %%
#5 Find and list the row for this customer

# %%
customersSquery = "SELECT * FROM Customers"

# %%
customers = pd.read_sql(customersSquery, conn)

# %%
customers
# Out:
#     index  Customer_Number                                            Company  \
# 0       0            25058                                  Path Construction
# 1       1            26069                              Big Lift Construction
# 2       2            26858                                     Primary Supply
# 3       3            31782                             Foresight Construction
# 4       4            32791                                Aspire Construction
# 5       5            35549                               Certain Construction
# 6       6            37139                             Accelerate Your Supply
# 7       7            37179                    Construction Recovery and Renew
# 8       8            39513                                  Building Capacity
# 9       9            41085  Opportune SupplyClick to check domain availabi...
# 10     10            43711                                   Supply Solutions
# ...

# %%
customerdetailSquery = "SELECT * FROM Customers WHERE Customer_Number = " + str(bestcustomer)

# %%
customer = pd.read_sql(customerdetailSquery, conn)

# %%
customer
# Out:
#    index  Customer_Number               Company      City State
# 0      5            35549  Certain Construction  Honolulu    HI
